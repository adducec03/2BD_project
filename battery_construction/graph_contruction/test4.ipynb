# %%
import itertools, json, math
from pathlib import Path
from typing import List, Set, Union

import networkx as nx
from pulp import (
    LpBinary,
    LpMaximize,
    LpProblem,
    LpStatus,
    LpVariable,
    PULP_CBC_CMD,
    lpSum,
)

# ---------------------------------------------------------------
# 1) LETTURA JSON
# ---------------------------------------------------------------
def load_circles(json_path:str, key="circles"):
    data = json.loads(Path(json_path).read_text())
    centers = [tuple(c["center"]) for c in data["circles"]]

    nodes = []
    for idx, c in enumerate(data[key]):
        if "center" in c:
            x, y = c["center"]
        else:
            x, y = c["x"], c["y"]
        nodes.append({"id": c.get("id", idx), "x": float(x), "y": float(y)})
    return nodes



# ---------------------------------------------------------------
# 2) GRAFO NON PESATO
# ---------------------------------------------------------------
def circles_to_graph(circles, r=18.0, tol=1.0):
    """due nodi adiacenti se |dist - 2r| <= tol"""
    target = 2 * r
    G = nx.Graph()
    for c in circles:
        G.add_node(c["id"], **c)

    for a, b in itertools.combinations(circles, 2):
        if abs(math.dist((a["x"], a["y"]), (b["x"], b["y"])) - target) <= tol:
            G.add_edge(a["id"], b["id"])
    return G


# ---------------------------------------------------------------
# 3-bis) GREEDY per il seed
# ---------------------------------------------------------------
def greedy_seed(G: nx.Graph, S: int, P: int) -> List[Set[int]]:
    comps, free = [], set(G.nodes)
    for _ in range(S):
        root = max(free, key=lambda v: G.degree(v))
        comp, front = {root}, [root]
        while len(comp) < P and front:
            v = front.pop(0)
            for u in G.neighbors(v):
                if u in free and u not in comp:
                    comp.add(u)
                    front.append(u)
                if len(comp) == P:
                    break
        # riempi se mancano nodi (caso rado, ma sicuro)
        if len(comp) < P:
            comp.update(list(free - comp)[: P - len(comp)])
        comps.append(comp)
        free -= comp
    if any(len(c) < P for c in comps):
        raise ValueError("Greedy fallita: partizionamento incompleto")
    return comps


# ---------------------------------------------------------------
# 3) ILP con warm-start
# ---------------------------------------------------------------


def dense_connected_partition(G: nx.Graph,
                              S: int,                 # nº componenti
                              P: int,                 # nodi per componente
                              *,
                              seed=None,              # lista di insiemi
                              max_seconds=60,
                              frac_gap=0.05):
    """
    Partiziona il grafo G in S componenti connesse da P nodi massimizzando
    il nº di archi interni.  Restituisce (componenti, status CBC).

    * seed        – lista [ set(v_i) ] (facoltativa) per warm-start
    * max_seconds – tempo-limite in secondi
    * frac_gap    – gap relativo ammesso (0‥1)
    """
    # ---------- modello ----------
    prob = LpProblem("DensePartition", LpMaximize)

    # variabili x (nodo in componente)
    x = {(v, c): LpVariable(f"x_{v}_{c}", 0, 1, LpBinary)
         for v in G.nodes for c in range(S)}
    # variabili y (arco interno)
    y = {(u, v, c): LpVariable(f"y_{u}_{v}_{c}", 0, 1, LpBinary)
         for u, v in G.edges for c in range(S)}
    # flusso orientato su entrambi i versi
    f = {(u, v, c): LpVariable(f"f_{u}_{v}_{c}", 0)
         for u, v in G.edges for c in range(S)}
    f.update({(v, u, c): LpVariable(f"f_{v}_{u}_{c}", 0)
              for u, v in G.edges for c in range(S)})
    # radici scelte dal solver
    r = {(v, c): LpVariable(f"root_{v}_{c}", 0, 1, LpBinary)
         for v in G.nodes for c in range(S)}

    # ---------- warm-start ----------
    if seed:
        for c, comp in enumerate(seed):
            for v in comp:                 # suggerisce la partizione
                x[v, c].setInitialValue(1)
            root = min(comp)               # radice candidata (facolt.)
            r[root, c].setInitialValue(1)
    # ---------------------------------

    # ---------- vincoli ----------
    # (1) esattamente P nodi per componente
    for c in range(S):
        prob += lpSum(x[v, c] for v in G.nodes) == P

    # (2) ogni nodo in una sola componente
    for v in G.nodes:
        prob += lpSum(x[v, c] for c in range(S)) == 1

    # (3) coerenza arco–nodi
    for (u, v) in G.edges:
        for c in range(S):
            prob += y[u, v, c] <= x[u, c]
            prob += y[u, v, c] <= x[v, c]

    # (4) bilancio di flusso per garantire connettività
    for c in range(S):
        for v in G.nodes:
            infl  = lpSum(f[u, v, c] for u in G.neighbors(v))
            outfl = lpSum(f[v, u, c] for u in G.neighbors(v))
            prob += outfl - infl == P * r[v, c] - x[v, c]

        for (u, v) in G.edges:
            prob += f[u, v, c] <= (P - 1) * y[u, v, c]
            prob += f[v, u, c] <= (P - 1) * y[u, v, c]

        # (4b) una sola radice per componente
        prob += lpSum(r[v, c] for v in G.nodes) == 1

    # ---------- obiettivo ----------
    prob += lpSum(y[u, v, c] for (u, v) in G.edges for c in range(S))

    # ---------- risoluzione ----------
    solver = PULP_CBC_CMD(
        msg=True,
        timeLimit=max_seconds,
        gapRel=frac_gap,
        options=["heur=on", "fpump=on"]
    )
    prob.solve(solver)

    status = LpStatus[prob.status]          # 'Optimal', 'Feasible', …

    if status not in ("Optimal", "Feasible"):
        raise RuntimeError(f"Solver exit: {status}")

    # componenti come liste di nodi
    comps = [
        [v for v in G.nodes if x[v, c].value() > 0.5]
        for c in range(S)
    ]
    return comps, status


# ---------------------------------------------------------------
# 4) MAIN
# ---------------------------------------------------------------
if __name__ == "__main__":
    S, P = 5, 25
    circles = load_circles("my_circles.json")
    G = circles_to_graph(circles, r=18.0, tol=1.0)

    print(f"Nodi: {len(G)}   Archi: {G.number_of_edges()}")
    print(f"Grado minimo: {min(dict(G.degree()).values())}")

    # seed greedy
    seed = greedy_seed(G, S, P)
    

    comps, status = dense_connected_partition(
        G, S, P, seed=seed, max_seconds=60, frac_gap=0.05
    )
    print(f"Solver status: {status}")
    for i, c in enumerate(comps, 1):
        print(f"Comp {i}: {len(c)} nodi  ->  {c[:8]}{' …' if len(c)>8 else ''}")
# Out:
# Nodi: 125   Archi: 327
# Grado minimo: 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/20/448h2f1933x4jpn5p3l2lb7c0000gn/T/fe2a3a459c1d4892bf44f712fb9c821f-pulp.mps -max -sec 60 -heur=on -fpump=on -ratio 0.05 -timeMode elapsed -branch -printingOptions all -solution /var/folders/20/448h2f1933x4jpn5p3l2lb7c0000gn/T/fe2a3a459c1d4892bf44f712fb9c821f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7305 COLUMNS
# At line 37456 RHS
# At line 44757 BOUNDS
# At line 47643 ENDATA
# Problem MODEL has 7300 rows, 6155 columns and 22745 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# No match for fpump - ? for list of commands
# ratioGap was changed from 0 to 0.05
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 327 - 1.34 seconds
# Cgl0004I processed model has 7300 rows, 6155 columns (2885 integer (2885 of which binary)) and 22745 elements
# Cbc0038I Initial state - 2682 integers unsatisfied sum - 457
# Cbc0038I Pass   1: (1.80 seconds) suminf.    5.00000 (125) obj. 0 iterations 4919
# Cbc0038I Pass   2: (1.81 seconds) suminf.    5.00000 (125) obj. 0 iterations 20
# Cbc0038I Pass   3: (1.82 seconds) suminf.    5.50000 (125) obj. -0.5 iterations 457
# Cbc0038I Pass   4: (1.88 seconds) suminf.    8.04437 (157) obj. -10.5796 iterations 1775
# Cbc0038I Pass   5: (1.91 seconds) suminf.    5.00000 (116) obj. -9 iterations 1027
# Cbc0038I Pass   6: (1.93 seconds) suminf.    5.45833 (116) obj. -9.45833 iterations 440
# Cbc0038I Pass   7: (1.97 seconds) suminf.    8.11995 (168) obj. -23.3395 iterations 1449
# Cbc0038I Pass   8: (2.00 seconds) suminf.    5.00000 (103) obj. -22 iterations 799
# Cbc0038I Pass   9: (2.02 seconds) suminf.    5.62500 (103) obj. -22.625 iterations 460
# Cbc0038I Pass  10: (2.08 seconds) suminf.    8.22545 (149) obj. -31.369 iterations 1761
# Cbc0038I Pass  11: (2.11 seconds) suminf.    5.00000 (96) obj. -30 iterations 791
# Cbc0038I Pass  12: (2.13 seconds) suminf.    5.75000 (96) obj. -30.75 iterations 481
# Cbc0038I Pass  13: (2.18 seconds) suminf.    8.95283 (144) obj. -32.5417 iterations 1640
# Cbc0038I Pass  14: (2.21 seconds) suminf.    5.00000 (95) obj. -31 iterations 886
# Cbc0038I Pass  15: (2.23 seconds) suminf.    5.91667 (95) obj. -31.9167 iterations 630
# Cbc0038I Pass  16: (2.27 seconds) suminf.    7.06688 (109) obj. -39.0524 iterations 1456
# Cbc0038I Pass  17: (2.30 seconds) suminf.    5.00000 (88) obj. -38 iterations 813
# Cbc0038I Pass  18: (2.31 seconds) suminf.    5.54167 (88) obj. -38.5417 iterations 341
# Cbc0038I Pass  19: (2.36 seconds) suminf.    9.75393 (115) obj. -40.3144 iterations 1419
# Cbc0038I Pass  20: (2.39 seconds) suminf.    5.00000 (88) obj. -38 iterations 750
# Cbc0038I Pass  21: (2.40 seconds) suminf.    5.00000 (88) obj. -38 iterations 9
# Cbc0038I Pass  22: (2.43 seconds) suminf.    6.16667 (88) obj. -39.1667 iterations 596
# Cbc0038I Pass  23: (2.47 seconds) suminf.   12.45573 (117) obj. -40.4974 iterations 1195
# Cbc0038I Pass  24: (2.50 seconds) suminf.    5.00000 (87) obj. -40 iterations 836
# Cbc0038I Pass  25: (2.50 seconds) suminf.    5.00000 (87) obj. -40 iterations 6
# Cbc0038I Pass  26: (2.53 seconds) suminf.    6.08333 (87) obj. -41.0833 iterations 710
# Cbc0038I Pass  27: (2.57 seconds) suminf.    8.54378 (114) obj. -49.2503 iterations 1292
# Cbc0038I Pass  28: (2.59 seconds) suminf.    5.00000 (79) obj. -48 iterations 730
# Cbc0038I Pass  29: (2.61 seconds) suminf.    5.83333 (79) obj. -48.8333 iterations 493
# Cbc0038I Pass  30: (2.65 seconds) suminf.    6.81710 (97) obj. -53.0417 iterations 1287
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 109 integers at bound fixed and 2696 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.84 seconds)
# Cbc0038I Full problem 7301 rows 6155 columns, reduced to 7301 rows 6155 columns - too large
# Cbc0038I After 3.04 seconds - Feasibility pump exiting - took 1.57 seconds
# Cbc0031I 277 added rows had average density of 416.48736
# Cbc0013I At root node, 277 cuts changed objective from -327 to -319.41754 in 37 passes
# Cbc0014I Cut generator 0 (Probing) - 21 row cuts average 2.0 elements, 0 column cuts (205 active)  in 0.181 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 661 row cuts average 888.9 elements, 0 column cuts (0 active)  in 13.186 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.309 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.378 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 13.825 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 535 row cuts average 6.2 elements, 0 column cuts (0 active)  in 0.161 seconds - new frequency is 1
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 1e+50 (best possible -319.41754), took 35512 iterations and 0 nodes (61.70 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -327 to -319.418
# Probing was tried 37 times and created 21 cuts of which 205 were active after adding rounds of cuts (0.181 seconds)
# Gomory was tried 37 times and created 661 cuts of which 0 were active after adding rounds of cuts (13.186 seconds)
# Knapsack was tried 37 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.309 seconds)
# Clique was tried 37 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.378 seconds)
# MixedIntegerRounding2 was tried 37 times and created 0 cuts of which 0 were active after adding rounds of cuts (13.825 seconds)
# FlowCover was tried 36 times and created 535 cuts of which 0 were active after adding rounds of cuts (0.161 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.123 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.366 seconds)
#
# Result - Stopped on time limit
#
# No feasible solution found
# Upper bound:                    319.418
# Enumerated nodes:               0
# Total iterations:               35512
# Time (CPU seconds):             61.15
# Time (Wallclock seconds):       61.73
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       61.17   (Wallclock seconds):       61.77
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 192
#     188 # seed greedy
#     189 seed = greedy_seed(G, S, P)
# --> 192 comps, status = dense_connected_partition(
#     193     G, S, P, seed=seed, max_seconds=60, frac_gap=0.05
#     194 )
#     195 print(f"Solver status: {status}")
#     196 for i, c in enumerate(comps, 1):
#
# Cell In[25], line 167, in dense_connected_partition(G, S, P, seed, max_seconds, frac_gap)
#     164 status = LpStatus[prob.status]          # 'Optimal', 'Feasible', …
#     166 if status not in ("Optimal", "Feasible"):
# --> 167     raise RuntimeError(f"Solver exit: {status}")
#     169 # componenti come liste di nodi
#     170 comps = [
#     171     [v for v in G.nodes if x[v, c].value() > 0.5]
#     172     for c in range(S)
#     173 ]
#
# RuntimeError: Solver exit: Not Solved

# %%
import pulp
print(pulp.__version__)     # vedrai 1.x
# Out:
# 3.0.2

# %%
import itertools, json, math
from pathlib import Path
from typing import List, Set, Union

import networkx as nx
from pulp import (
    LpBinary,
    LpMaximize,
    LpProblem,
    LpStatus,
    LpVariable,
    PULP_CBC_CMD,
    lpSum,
)

# ---------------------------------------------------------------
# 1) LETTURA JSON
# ---------------------------------------------------------------
def load_circles(json_path:str, key="circles"):
    data = json.loads(Path(json_path).read_text())
    centers = [tuple(c["center"]) for c in data["circles"]]

    nodes = []
    for idx, c in enumerate(data[key]):
        if "center" in c:
            x, y = c["center"]
        else:
            x, y = c["x"], c["y"]
        nodes.append({"id": c.get("id", idx), "x": float(x), "y": float(y)})
    return nodes



# ---------------------------------------------------------------
# 2) GRAFO NON PESATO
# ---------------------------------------------------------------
def circles_to_graph(circles, r=18.0, tol=1.0):
    """due nodi adiacenti se |dist - 2r| <= tol"""
    target = 2 * r
    G = nx.Graph()
    for c in circles:
        G.add_node(c["id"], **c)

    for a, b in itertools.combinations(circles, 2):
        if abs(math.dist((a["x"], a["y"]), (b["x"], b["y"])) - target) <= tol:
            G.add_edge(a["id"], b["id"])
    return G


# ---------------------------------------------------------------
# 3-bis) GREEDY per il seed
# ---------------------------------------------------------------
def greedy_seed(G: nx.Graph, S: int, P: int) -> List[Set[int]]:
    comps, free = [], set(G.nodes)
    for _ in range(S):
        root = max(free, key=lambda v: G.degree(v))
        comp, front = {root}, [root]
        while len(comp) < P and front:
            v = front.pop(0)
            for u in G.neighbors(v):
                if u in free and u not in comp:
                    comp.add(u)
                    front.append(u)
                if len(comp) == P:
                    break
        # riempi se mancano nodi (caso rado, ma sicuro)
        if len(comp) < P:
            comp.update(list(free - comp)[: P - len(comp)])
        comps.append(comp)
        free -= comp
    if any(len(c) < P for c in comps):
        raise ValueError("Greedy fallita: partizionamento incompleto")
    return comps


# ---------------------------------------------------------------
# 3) ILP con warm-start
# ---------------------------------------------------------------


import itertools
from typing import List, Tuple, Dict
import networkx as nx
from pulp import LpBinary, LpMaximize, LpProblem, LpVariable, lpSum, PULP_CBC_CMD, LpStatus


def dense_connected_partition(G: nx.Graph, S: int, P: int, seed: List[List[int]] = None, max_seconds: int = 300, frac_gap: float = 0.05) -> Tuple[List[List[int]], str]:
    prob = LpProblem("DensePartition", LpMaximize)

    # Variabili di partizione
    x = {(v, c): LpVariable(f"x_{v}_{c}", cat=LpBinary) for v in G.nodes for c in range(S)}
    y = {(u, v, c): LpVariable(f"y_{u}_{v}_{c}", cat=LpBinary) for u, v in G.edges for c in range(S)}
    y.update({(v, u, c): LpVariable(f"y_{v}_{u}_{c}", cat=LpBinary) for u, v in G.edges for c in range(S)})
    f = {(u, v, c): LpVariable(f"f_{u}_{v}_{c}", lowBound=0) for u, v in G.edges for c in range(S)}
    f.update({(v, u, c): LpVariable(f"f_{v}_{u}_{c}", lowBound=0) for u, v in G.edges for c in range(S)})
    rvar = {(v, c): LpVariable(f"root_{v}_{c}", cat=LpBinary) for v in G.nodes for c in range(S)}

    # Inizializzazione con il seed
    # ---- Warm-start con soluzione greedy --------------------------------------
    if seed:
        for c, comp in enumerate(seed):
            comp_list = list(comp)  # Converti il set in una lista
            for v in comp_list:
                x[v, c].setInitialValue(1)
                rvar[v, c].setInitialValue(1 if v == comp_list[0] else 0)

    # Vincoli per la connettività
    for c in range(S):
        # Ogni partizione ha esattamente P nodi
        prob += lpSum(x[v, c] for v in G.nodes) == P

        # Una sola radice per componente
        prob += lpSum(rvar[v, c] for v in G.nodes) == 1

        # Radice deve essere parte della componente
        for v in G.nodes:
            prob += rvar[v, c] <= x[v, c]

        # Flusso di connessione
        for v in G.nodes:
            in_flow = lpSum(f[u, v, c] for u in G.neighbors(v))
            out_flow = lpSum(f[v, u, c] for u in G.neighbors(v))
            prob += out_flow - in_flow == P * rvar[v, c] - x[v, c]

        # Coerenza arco-nodo
        for (u, v) in G.edges:
            prob += y[u, v, c] <= x[u, c]
            prob += y[u, v, c] <= x[v, c]
            prob += f[u, v, c] <= (P - 1) * y[u, v, c]
            prob += f[v, u, c] <= (P - 1) * y[v, u, c]

    # Vincoli di partizione (ogni nodo in una sola componente)
    for v in G.nodes:
        prob += lpSum(x[v, c] for c in range(S)) == 1

    # Funzione obiettivo: massimizza archi interni
    prob += lpSum(y[u, v, c] for (u, v) in G.edges for c in range(S))

    # Parametri del solver
    solver = PULP_CBC_CMD(
        msg=True,
        options=[
            "sec", str(max_seconds),
            "ratio", str(frac_gap),
            "heur", "on",
            "fpump", "on"
        ]
    )

    # Risoluzione del problema
    prob.solve(solver)
    status = LpStatus[prob.status]

    if status not in ("Optimal", "Feasible"):
        raise RuntimeError(f"Solver exit: {status}")

    # Estrai le componenti
    components = [[v for v in G.nodes if x[v, c].value() > 0.5] for c in range(S)]
    return components, status


# ---------------------------------------------------------------
# 4) MAIN
# ---------------------------------------------------------------
if __name__ == "__main__":
    S, P = 5, 25
    circles = load_circles("my_circles.json")
    G = circles_to_graph(circles, r=18.0, tol=1.0)

    print(f"Nodi: {len(G)}   Archi: {G.number_of_edges()}")
    print(f"Grado minimo: {min(dict(G.degree()).values())}")

    # seed greedy
    seed = greedy_seed(G, S, P)
    

    comps, status = dense_connected_partition(
        G, S, P, seed=seed, max_seconds=60, frac_gap=0.05
    )
    print(f"Solver status: {status}")
    for i, c in enumerate(comps, 1):
        print(f"Comp {i}: {len(c)} nodi  ->  {c[:8]}{' …' if len(c)>8 else ''}")
# Out:
# Nodi: 125   Archi: 327
# Grado minimo: 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/20/448h2f1933x4jpn5p3l2lb7c0000gn/T/f6cfc9d1f478481ca6faffd60ee31276-pulp.mps -max -sec -60 -ratio -0.05 -heur -on -fpump -on -timeMode elapsed -branch -printingOptions all -solution /var/folders/20/448h2f1933x4jpn5p3l2lb7c0000gn/T/f6cfc9d1f478481ca6faffd60ee31276-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7930 COLUMNS
# At line 42601 RHS
# At line 50527 BOUNDS
# At line 55048 ENDATA
# Problem MODEL has 7925 rows, 7790 columns and 23995 elements
# Coin0008I MODEL read with 0 errors
# -60 was provided for seconds - valid range is -1 to 1.79769e+308
# -0.05 was provided for ratioGap - valid range is 0 to 1.79769e+308
# heuristicsOnOff has value on
# No match for on - ? for list of commands
# No match for fpump - ? for list of commands
# No match for on - ? for list of commands
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 177
#     173 # seed greedy
#     174 seed = greedy_seed(G, S, P)
# --> 177 comps, status = dense_connected_partition(
#     178     G, S, P, seed=seed, max_seconds=60, frac_gap=0.05
#     179 )
#     180 print(f"Solver status: {status}")
#     181 for i, c in enumerate(comps, 1):
#
# Cell In[27], line 151, in dense_connected_partition(G, S, P, seed, max_seconds, frac_gap)
#     140 solver = PULP_CBC_CMD(
#     141     msg=True,
#     142     options=[
#    (...)    147     ]
#     148 )
#     150 # Risoluzione del problema
# --> 151 prob.solve(solver)
#     152 status = LpStatus[prob.status]
#     154 if status not in ("Optimal", "Feasible"):
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/site-packages/pulp/pulp.py:2007, in LpProblem.solve(self, solver, **kwargs)
#    2005 # time it
#    2006 self.startClock()
# -> 2007 status = solver.actualSolve(self, **kwargs)
#    2008 self.stopClock()
#    2009 self.restoreObjective(wasNone, dummyVar)
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/site-packages/pulp/apis/coin_api.py:128, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     126 def actualSolve(self, lp: LpProblem, **kwargs):
#     127     """Solve a well formulated lp problem"""
# --> 128     return self.solve_CBC(lp, **kwargs)
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/site-packages/pulp/apis/coin_api.py:206, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     204 else:
#     205     cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 206 if cbc.wait() != 0:
#     207     if pipe:
#     208         pipe.close()
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/subprocess.py:1276, in Popen.wait(self, timeout)
#    1274     endtime = _time() + timeout
#    1275 try:
# -> 1276     return self._wait(timeout=timeout)
#    1277 except KeyboardInterrupt:
#    1278     # https://bugs.python.org/issue25942
#    1279     # The first keyboard interrupt waits briefly for the child to
#    1280     # exit under the common assumption that it also received the ^C
#    1281     # generated SIGINT and will exit rapidly.
#    1282     if timeout is not None:
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/subprocess.py:2068, in Popen._wait(self, timeout)
#    2066 if self.returncode is not None:
#    2067     break  # Another thread waited.
# -> 2068 (pid, sts) = self._try_wait(0)
#    2069 # Check the pid and loop as waitpid has been known to
#    2070 # return 0 even without WNOHANG in odd situations.
#    2071 # http://bugs.python.org/issue14396.
#    2072 if pid == self.pid:
#
# File /opt/anaconda3/envs/tirocinio_IA/lib/python3.13/subprocess.py:2026, in Popen._try_wait(self, wait_flags)
#    2024 """All callers to this function MUST hold self._waitpid_lock."""
#    2025 try:
# -> 2026     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2027 except ChildProcessError:
#    2028     # This happens if SIGCLD is set to be ignored or waiting
#    2029     # for child processes has otherwise been disabled for our
#    2030     # process.  This child is dead, we can't get the status.
#    2031     pid = self.pid
#
# KeyboardInterrupt:
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 327 - 0.67 seconds
# Cgl0004I processed model has 6290 rows, 6155 columns (2885 integer (2885 of which binary)) and 20725 elements
# Cbc0038I Initial state - 2646 integers unsatisfied sum - 457
# Cbc0038I Pass   1: (1.15 seconds) suminf.    6.42333 (48) obj. 0 iterations 4552
# Cbc0038I Pass   2: (1.17 seconds) suminf.    3.77333 (30) obj. -0.333333 iterations 285
# Cbc0038I Pass   3: (1.18 seconds) suminf.    2.28833 (17) obj. -1.20833 iterations 310
# Cbc0038I Pass   4: (1.19 seconds) suminf.    2.24667 (20) obj. -1.16667 iterations 56
# Cbc0038I Pass   5: (1.20 seconds) suminf.    1.57167 (10) obj. -4.29167 iterations 410
# Cbc0038I Pass   6: (1.21 seconds) suminf.    1.25167 (10) obj. -4.29167 iterations 77
# Cbc0038I Pass   7: (1.22 seconds) suminf.    0.48000 (4) obj. -7 iterations 189
# Cbc0038I Pass   8: (1.23 seconds) suminf.    0.16000 (4) obj. -7 iterations 68
# Cbc0038I Pass   9: (1.24 seconds) suminf.    1.28000 (7) obj. -7 iterations 139
# Cbc0038I Pass  10: (1.25 seconds) suminf.    0.96000 (7) obj. -7 iterations 60
# Cbc0038I Pass  11: (1.27 seconds) suminf.    5.81014 (36) obj. -17.5652 iterations 627
# Cbc0038I Pass  12: (1.29 seconds) suminf.    2.08333 (15) obj. -18.0833 iterations 439
# Cbc0038I Pass  13: (1.30 seconds) suminf.    0.16333 (3) obj. -19.0833 iterations 199
# Cbc0038I Pass  14: (1.30 seconds) suminf.    0.16333 (3) obj. -19.0833 iterations 37
# Cbc0038I Pass  15: (1.31 seconds) suminf.    1.04167 (6) obj. -20.0417 iterations 177
# Cbc0038I Pass  16: (1.32 seconds) suminf.    1.00000 (5) obj. -20 iterations 72
# Cbc0038I Pass  17: (1.33 seconds) suminf.    0.08000 (2) obj. -20 iterations 74
# Cbc0038I Pass  18: (1.33 seconds) suminf.    0.08000 (2) obj. -20 iterations 11
# Cbc0038I Pass  19: (1.35 seconds) suminf.    0.32000 (4) obj. -23 iterations 367
# Cbc0038I Pass  20: (1.37 seconds) suminf.    0.08000 (2) obj. -23 iterations 257
# Cbc0038I Pass  21: (1.38 seconds) suminf.    0.68167 (5) obj. -23.0417 iterations 104
# Cbc0038I Pass  22: (1.38 seconds) suminf.    0.32000 (4) obj. -23 iterations 63
# Cbc0038I Pass  23: (1.39 seconds) suminf.    0.08000 (2) obj. -23 iterations 60
# Cbc0038I Pass  24: (1.41 seconds) suminf.    8.70479 (34) obj. -28.7031 iterations 527
# Cbc0038I Pass  25: (1.43 seconds) suminf.    1.82167 (12) obj. -28.625 iterations 364
# Cbc0038I Pass  26: (1.44 seconds) suminf.    1.32500 (11) obj. -29.125 iterations 57
# Cbc0038I Pass  27: (1.45 seconds) suminf.    0.48333 (4) obj. -32.0833 iterations 188
# Cbc0038I Pass  28: (1.46 seconds) suminf.    0.12167 (3) obj. -32.0417 iterations 87
# Cbc0038I Pass  29: (1.46 seconds) suminf.    0.44167 (3) obj. -33.0417 iterations 87
# Cbc0038I Pass  30: (1.47 seconds) suminf.    0.08000 (2) obj. -33 iterations 62
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 210 integers at bound fixed and 2509 continuous
# Cbc0038I Full problem 6290 rows 6155 columns, reduced to 3232 rows 2495 columns
# Cbc0038I Mini branch and bound did not improve solution (5.36 seconds)
# Cbc0038I Full problem 6291 rows 6155 columns, reduced to 6291 rows 6155 columns - too large
# Cbc0038I After 5.59 seconds - Feasibility pump exiting - took 4.74 seconds
# Cbc0031I 331 added rows had average density of 298.91239
# Cbc0013I At root node, 331 cuts changed objective from -327 to -318.68468 in 50 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (278 active)  in 0.258 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 883 row cuts average 851.6 elements, 0 column cuts (0 active)  in 20.347 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.386 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.516 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 14.736 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 413 row cuts average 6.1 elements, 0 column cuts (0 active)  in 0.194 seconds - new frequency is 1
# Cbc0027I Exiting on user event
# Cbc0005I Partial search - best objective 1e+50 (best possible -318.68468), took 45396 iterations and 0 nodes (116.16 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -327 to -318.685
# Probing was tried 50 times and created 0 cuts of which 278 were active after adding rounds of cuts (0.258 seconds)
# Gomory was tried 50 times and created 883 cuts of which 0 were active after adding rounds of cuts (20.347 seconds)
# Knapsack was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.386 seconds)
# Clique was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.516 seconds)
# MixedIntegerRounding2 was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (14.736 seconds)
# FlowCover was tried 50 times and created 413 cuts of which 0 were active after adding rounds of cuts (0.194 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.116 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.348 seconds)
#
# Result - User ctrl-cuser ctrl-c
#
# No feasible solution found
# Upper bound:                    318.685
# Enumerated nodes:               0
# Total iterations:               45396
# Time (CPU seconds):             115.25
# Time (Wallclock seconds):       116.22
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       115.28   (Wallclock seconds):       116.26
